# %%
import PIL
from PIL import Image
import os, sys

# %%
ls
# Out:
# 'COVID MULTI INPUT.ipynb'         TestSet/               testClinData.xls
# 'COVID SOLO IMMAGINI.ipynb'       TrainSet/              train1AllColumns.xls
# 'COVID SOLO TESTO.ipynb'          runs/                  train2Correlation.xls
# 'PREPROCESSING COVID CXR.ipynb'   test1AllColumns.xls    train3Oxygen.xls
#  RESIZE.ipynb                     test2Correlation.xls   trainClinData.xls
#  Resized_Trainset/                test3Oxygen.xls

# %%
path = "TrainSet/"
dirs = os.listdir( path )

# %%
path
# Out:
# 'TrainSet/'

# %%
dirs
# Out:
# ['P_2_62.png',
#  'P_232.png',
#  'P_720.png',
#  'P_2_67.png',
#  'P_2_9.png',
#  'P_98.png',
#  'P_759.png',
#  'P_667.png',
#  'P_2_19.png',
#  'P_795.png',
#  'P_619.png',
#  'P_289.png',
#  'P_493.png',
#  'P_486.png',
#  'P_1_154.png',
#  'P_2_88.png',
#  'P_412.png',
#  'P_1_112.png',
#  'P_460.png',
#  'P_130.png',
#  'P_654.png',
#  'P_405.png',
#  'P_45.png',
#  'P_782.png',
#  'P_827.png',
#  'P_1_107.png',
#  'P_753.png',
#  'P_786.png',
#  'P_507.png',
#  'P_719.png',
#  'P_497.png',
#  'P_310.png',
#  'P_743.png',
#  'P_446.png',
#  'P_13.png',
#  'P_382.png',
#  'P_1_8.png',
#  'P_2_93.png',
#  'P_442.png',
#  'P_2_70.png',
#  'P_559.png',
#  'P_19.png',
#  'P_245.png',
#  'P_2.png',
#  'P_42.png',
#  'P_1_143.png',
#  'P_328.png',
#  'P_2_27.png',
#  'P_2_102.png',
#  'P_1_126.png',
#  'P_1_57.png',
#  'P_793.png',
#  'P_292.png',
#  'P_527.png',
#  'P_693.png',
#  'P_58.png',
#  'P_715.png',
#  'P_431.png',
#  'P_780.png',
#  'P_625.png',
#  'P_2_99.png',
#  'P_704.png',
#  'P_754.png',
#  'P_455.png',
#  'P_819.png',
#  'P_2_13.png',
#  'P_56.png',
#  'P_426.png',
#  'P_1_29.png',
#  'P_227.png',
#  'P_303.png',
#  'P_1_153.png',
#  'P_1_19.png',
#  'P_355.png',
#  'P_64.png',
#  'P_810.png',
#  'P_131.png',
#  'P_188.png',
#  'P_444.png',
#  'P_229.png',
#  'P_691.png',
#  'P_2_47.png',
#  'P_2_81.png',
#  'P_370.png',
#  'P_822.png',
#  'P_789.png',
#  'P_1_144.png',
#  'P_407.png',
#  'P_1_80.png',
#  'P_501.png',
#  'P_670.png',
#  'P_814.png',
#  'P_275.png',
#  'P_26.png',
#  'P_603.png',
#  'P_1_122.png',
#  'P_186.png',
#  'P_1_78.png',
#  'P_733.png',
#  'P_1_1.png',
#  'P_300.png',
#  'P_332.png',
#  'P_558.png',
#  'P_402.png',
#  'P_363.png',
#  'P_797.png',
#  'P_55.png',
#  'P_2_73.png',
#  'P_209.png',
#  'P_220.png',
#  'P_441.png',
#  'P_809.png',
#  'P_172.png',
#  'P_440.png',
#  'P_2_100.png',
#  'P_799.png',
#  'P_775.png',
#  'P_1_31.png',
#  'P_190.png',
#  'P_2_7.png',
#  'P_379.png',
#  'P_1_17.png',
#  'P_552.png',
#  'P_333.png',
#  'P_270.png',
#  'P_360.png',
#  'P_2_63.png',
#  'P_771.png',
#  'P_158.png',
#  'P_2_58.png',
#  'P_517.png',
#  'P_213.png',
#  'P_144.png',
#  'P_75.png',
#  'P_418.png',
#  'P_485.png',
#  'P_137.png',
#  'P_92.png',
#  'P_263.png',
#  'P_802.png',
#  'P_216.png',
#  'P_828.png',
#  'P_1_10.png',
#  'P_243.png',
#  'P_745.png',
#  'P_265.png',
#  'P_175.png',
#  'P_356.png',
#  'P_339.png',
#  'P_1_70.png',
#  'P_2_117.png',
#  'P_48.png',
#  'P_401.png',
#  'P_738.png',
#  'P_415.png',
#  'P_551.png',
#  'P_398.png',
#  'P_1_113.png',
#  'P_756.png',
#  'P_512.png',
#  'P_586.png',
#  'P_197.png',
#  'P_1_121.png',
#  'P_2_57.png',
#  'P_364.png',
#  'P_622.png',
#  'P_1_148.png',
#  'P_161.png',
#  'P_240.png',
#  'P_577.png',
#  'P_705.png',
#  'P_1_130.png',
#  'P_1_87.png',
#  'P_403.png',
#  'P_647.png',
#  'P_2_90.png',
#  'P_628.png',
#  'P_1_81.png',
#  'P_776.png',
#  'P_299.png',
#  'P_1_123.png',
#  'P_573.png',
#  'P_241.png',
#  'P_723.png',
#  'P_268.png',
#  'P_498.png',
#  'P_476.png',
#  'P_532.png',
#  'P_623.png',
#  'P_330.png',
#  'P_369.png',
#  'P_737.png',
#  'P_2_51.png',
#  'P_1_60.png',
#  'P_141.png',
#  'P_322.png',
#  'P_372.png',
#  'P_183.png',
#  'P_95.png',
#  'P_760.png',
#  'P_461.png',
#  'P_377.png',
#  'P_614.png',
#  'P_116.png',
#  'P_801.png',
#  'P_57.png',
#  'P_556.png',
#  'P_447.png',
#  'P_1_55.png',
#  'P_1_56.png',
#  'P_1_162.png',
#  'P_752.png',
#  'P_830.png',
#  'P_121.png',
#  'P_458.png',
#  'P_832.png',
#  'P_1_52.png',
#  'P_750.png',
#  'P_408.png',
#  'P_762.png',
#  'P_389.png',
#  'P_317.png',
#  'P_127.png',
#  'P_522.png',
#  'P_770.png',
#  'P_284.png',
#  'P_11.png',
#  'P_46.png',
#  'P_544.png',
#  'P_2_22.png',
#  'P_1_77.png',
#  'P_2_42.png',
#  'P_562.png',
#  'P_168.png',
#  'P_145.png',
#  'P_2_119.png',
#  'P_680.png',
#  'P_479.png',
#  'P_748.png',
#  'P_253.png',
#  'P_174.png',
#  'P_580.png',
#  'P_640.png',
#  'P_2_3.png',
#  'P_51.png',
#  'P_711.png',
#  'P_2_97.png',
#  'P_187.png',
#  'P_781.png',
#  'P_646.png',
#  'P_594.png',
#  'P_1_161.png',
#  'P_90.png',
#  'P_1_61.png',
#  'P_1_62.png',
#  'P_634.png',
#  'P_487.png',
#  'P_1_13.png',
#  'P_2_40.png',
#  'P_117.png',
#  'P_2_74.png',
#  'P_367.png',
#  'P_2_33.png',
#  'P_710.png',
#  'P_2_2.png',
#  'P_2_23.png',
#  'P_1_63.png',
#  'P_1_106.png',
#  'P_1_72.png',
#  'P_468.png',
#  'P_837.png',
#  'P_1_35.png',
#  'P_305.png',
#  'P_396.png',
#  'P_2_34.png',
#  'P_59.png',
#  'P_736.png',
#  'P_568.png',
#  'P_210.png',
#  'P_81.png',
#  'P_266.png',
#  'P_496.png',
#  'P_391.png',
#  'P_163.png',
#  'P_601.png',
#  'P_2_59.png',
#  'P_2_94.png',
#  'P_436.png',
#  'P_219.png',
#  'P_1_37.png',
#  'P_1_18.png',
#  'P_617.png',
#  'P_536.png',
#  'P_613.png',
#  'P_357.png',
#  'P_298.png',
#  'P_655.png',
#  'P_438.png',
#  'P_264.png',
#  'P_38.png',
#  'P_2_61.png',
#  'P_1_163.png',
#  'P_1_44.png',
#  'P_288.png',
#  'P_140.png',
#  'P_2_76.png',
#  'P_732.png',
#  'P_96.png',
#  'P_104.png',
#  'P_629.png',
#  'P_1_120.png',
#  'P_1_110.png',
#  'P_2_96.png',
#  'P_598.png',
#  'P_1_115.png',
#  'P_119.png',
#  'P_157.png',
#  'P_2_87.png',
#  'P_2_46.png',
#  'P_34.png',
#  'P_702.png',
#  'P_648.png',
#  'P_29.png',
#  'P_67.png',
#  'P_43.png',
#  'P_178.png',
#  'P_2_111.png',
#  'P_295.png',
#  'P_423.png',
#  'P_125.png',
#  'P_539.png',
#  'P_1_12.png',
#  'P_65.png',
#  'P_1_138.png',
#  'P_600.png',
#  'P_1_132.png',
#  'P_378.png',
#  'P_724.png',
#  'P_106.png',
#  'P_758.png',
#  'P_80.png',
#  'P_668.png',
#  'P_198.png',
#  'P_225.png',
#  'P_1_119.png',
#  'P_165.png',
#  'P_312.png',
#  'P_340.png',
#  'P_478.png',
#  'P_205.png',
#  'P_76.png',
#  'P_353.png',
#  'P_1_16.png',
#  'P_234.png',
#  'P_449.png',
#  'P_335.png',
#  'P_766.png',
#  'P_679.png',
#  'P_259.png',
#  'P_49.png',
#  'P_318.png',
#  'P_36.png',
#  'P_25.png',
#  'P_816.png',
#  'P_314.png',
#  'P_153.png',
#  'P_2_92.png',
#  'P_1_46.png',
#  'P_148.png',
#  'P_505.png',
#  'P_2_24.png',
#  'P_2_39.png',
#  'P_2_41.png',
#  'P_611.png',
#  'P_826.png',
#  'P_179.png',
#  'P_115.png',
#  'P_2_26.png',
#  'P_1_102.png',
#  'P_2_15.png',
#  'P_698.png',
#  'P_576.png',
#  'P_674.png',
#  'P_500.png',
#  'P_1_39.png',
#  'P_584.png',
#  'P_2_4.png',
#  'P_1_88.png',
#  'P_639.png',
#  'P_774.png',
#  'P_712.png',
#  'P_579.png',
#  'P_278.png',
#  'P_154.png',
#  'P_1_6.png',
#  'P_218.png',
#  'P_2_56.png',
#  'P_764.png',
#  'P_427.png',
#  'P_740.png',
#  'P_54.png',
#  'P_85.png',
#  'P_272.png',
#  'P_386.png',
#  'P_1_33.png',
#  'P_2_83.png',
#  'P_2_17.png',
#  'P_108.png',
#  'P_721.png',
#  'P_404.png',
#  'P_1_53.png',
#  'P_835.png',
#  'P_206.png',
#  'P_231.png',
#  'P_380.png',
#  'P_78.png',
#  'P_50.png',
#  'P_524.png',
#  'P_126.png',
#  'P_593.png',
#  'P_35.png',
#  'P_540.png',
#  'P_2_109.png',
#  'P_365.png',
#  'P_419.png',
#  'P_196.png',
#  'P_71.png',
#  'P_169.png',
#  'P_843.png',
#  'P_804.png',
#  'P_631.png',
#  'P_609.png',
#  'P_2_32.png',
#  'P_2_122.png',
#  'P_2_37.png',
#  'P_537.png',
#  'P_2_35.png',
#  'P_451.png',
#  'P_474.png',
#  'P_794.png',
#  'P_2_113.png',
#  'P_1_14.png',
#  'P_695.png',
#  'P_385.png',
#  'P_375.png',
#  'P_191.png',
#  'P_2_36.png',
#  'P_86.png',
#  'P_657.png',
#  'P_687.png',
#  'P_149.png',
#  'P_1_89.png',
#  'P_132.png',
#  'P_325.png',
#  'P_473.png',
#  'P_123.png',
#  'P_567.png',
#  'P_239.png',
#  'P_1_155.png',
#  'P_1_2.png',
#  'P_1_111.png',
#  'P_767.png',
#  'P_337.png',
#  'P_534.png',
#  'P_1_11.png',
#  'P_467.png',
#  'P_1_114.png',
#  'P_511.png',
#  'P_388.png',
#  'P_2_72.png',
#  'P_306.png',
#  'P_784.png',
#  'P_1_83.png',
#  'P_351.png',
#  'P_235.png',
#  'P_555.png',
#  'P_652.png',
#  'P_626.png',
#  'P_1_58.png',
#  'P_383.png',
#  'P_459.png',
#  'P_508.png',
#  'P_817.png',
#  'P_31.png',
#  'P_17.png',
#  'P_143.png',
#  'P_798.png',
#  'P_316.png',
#  'P_642.png',
#  'P_420.png',
#  'P_630.png',
#  'P_744.png',
#  'P_591.png',
#  'P_516.png',
#  'P_751.png',
#  'P_1_158.png',
#  'P_373.png',
#  'P_834.png',
#  'P_135.png',
#  'P_836.png',
#  'P_1_24.png',
#  'P_803.png',
#  'P_627.png',
#  'P_645.png',
#  'P_528.png',
#  'P_761.png',
#  'P_184.png',
#  'P_311.png',
#  'P_592.png',
#  'P_521.png',
#  'P_502.png',
#  'P_146.png',
#  'P_2_65.png',
#  'P_2_45.png',
#  'P_129.png',
#  'P_327.png',
#  'P_818.png',
#  'P_839.png',
#  'P_277.png',
#  'P_718.png',
#  'P_489.png',
#  'P_362.png',
#  'P_341.png',
#  'P_1_104.png',
#  'P_138.png',
#  'P_1_15.png',
#  'P_2_43.png',
#  'P_2_85.png',
#  'P_320.png',
#  'P_70.png',
#  'P_650.png',
#  'P_47.png',
#  'P_582.png',
#  'P_254.png',
#  'P_671.png',
#  'P_1_145.png',
#  'P_554.png',
#  'P_831.png',
#  'P_296.png',
#  'P_800.png',
#  'P_2_115.png',
#  'P_788.png',
#  'P_1_151.png',
#  'P_273.png',
#  'P_494.png',
#  'P_439.png',
#  'P_214.png',
#  'P_177.png',
#  'P_841.png',
#  'P_681.png',
#  'P_1_59.png',
#  'P_635.png',
#  'P_424.png',
#  'P_1_94.png',
#  'P_250.png',
#  'P_465.png',
#  'P_1.png',
#  'P_2_110.png',
#  'P_301.png',
#  'P_1_74.png',
#  'P_199.png',
#  'P_410.png',
#  'P_222.png',
#  'P_735.png',
#  'P_84.png',
#  'P_739.png',
#  'P_470.png',
#  'P_463.png',
#  'P_1_36.png',
#  'P_93.png',
#  'P_643.png',
#  'P_2_11.png',
#  'P_110.png',
#  'P_692.png',
#  'P_3.png',
#  'P_1_141.png',
#  'P_785.png',
#  'P_2_10.png',
#  'P_103.png',
#  'P_791.png',
#  'P_495.png',
#  'P_734.png',
#  'P_570.png',
#  'P_755.png',
#  'P_293.png',
#  'P_212.png',
#  'P_1_75.png',
#  'P_741.png',
#  'P_595.png',
#  'P_425.png',
#  'P_547.png',
#  'P_504.png',
#  'P_448.png',
#  'P_807.png',
#  'P_1_30.png',
#  'P_23.png',
#  'P_612.png',
#  'P_9.png',
#  'P_7.png',
#  'P_203.png',
#  'P_60.png',
#  'P_1_147.png',
#  'P_342.png',
#  'P_2_89.png',
#  'P_806.png',
#  'P_1_159.png',
#  'P_1_146.png',
#  'P_469.png',
#  'P_2_71.png',
#  'P_182.png',
#  'P_215.png',
#  'P_509.png',
#  'P_811.png',
#  'P_2_8.png',
#  'P_445.png',
#  'P_44.png',
#  'P_663.png',
#  'P_114.png',
#  'P_150.png',
#  'P_545.png',
#  'P_658.png',
#  'P_1_71.png',
#  'P_282.png',
#  'P_202.png',
#  'P_1_118.png',
#  'P_88.png',
#  'P_368.png',
#  'P_510.png',
#  'P_255.png',
#  'P_2_101.png',
#  'P_1_25.png',
#  'P_1_109.png',
#  'P_83.png',
#  'P_334.png',
#  'P_167.png',
#  'P_656.png',
#  'P_118.png',
#  'P_111.png',
#  'P_838.png',
#  'P_321.png',
#  'P_171.png',
#  'P_821.png',
#  'P_1_41.png',
#  'P_566.png',
#  'P_409.png',
#  'P_773.png',
#  'P_246.png',
#  'P_428.png',
#  'P_1_93.png',
#  'P_515.png',
#  'P_336.png',
#  'P_483.png',
#  'P_604.png',
#  'P_124.png',
#  'P_20.png',
#  'P_587.png',
#  'P_575.png',
#  'P_796.png',
#  'P_89.png',
#  'P_608.png',
#  'P_538.png',
#  'P_808.png',
#  'P_1_92.png',
#  'P_244.png',
#  'P_605.png',
#  'P_77.png',
#  'P_87.png',
#  'P_2_80.png',
#  'P_1_137.png',
#  'P_204.png',
#  'P_790.png',
#  'P_747.png',
#  'P_262.png',
#  'P_233.png',
#  'P_513.png',
#  'P_606.png',
#  'P_641.png',
#  'P_416.png',
#  'P_1_28.png',
#  'P_519.png',
#  'P_120.png',
#  'P_421.png',
#  'P_112.png',
#  'P_1_95.png',
#  'P_1_96.png',
#  'P_1_32.png',
#  'P_1_150.png',
#  'P_783.png',
#  'P_596.png',
#  'P_2_55.png',
#  'P_1_45.png',
#  'P_1_27.png',
#  'P_700.png',
#  'P_193.png',
#  'P_2_30.png',
#  'P_746.png',
#  'P_1_9.png',
#  'P_30.png',
#  'P_338.png',
#  'P_82.png',
#  'P_2_20.png',
#  'P_2_29.png',
#  'P_276.png',
#  'P_15.png',
#  'P_2_50.png',
#  'P_829.png',
#  'P_450.png',
#  'P_616.png',
#  'P_62.png',
#  'P_1_133.png',
#  'P_283.png',
#  'P_1_67.png',
#  'P_2_68.png',
#  'P_506.png',
#  'P_1_125.png',
#  'P_1_97.png',
#  'P_1_108.png',
#  'P_1_47.png',
#  'P_684.png',
#  'P_464.png',
#  'P_432.png',
#  'P_632.png',
#  'P_707.png',
#  'P_499.png',
#  'P_274.png',
#  'P_8.png',
#  'P_726.png',
#  'P_452.png',
#  'P_1_116.png',
#  'P_2_104.png',
#  'P_4.png',
#  'P_242.png',
#  'P_682.png',
#  'P_387.png',
#  'P_703.png',
#  'P_287.png',
#  'P_2_103.png',
#  'P_417.png',
#  'P_252.png',
#  'P_97.png',
#  'P_122.png',
#  'P_313.png',
#  'P_2_38.png',
#  'P_787.png',
#  'P_824.png',
#  'P_72.png',
#  'P_1_142.png',
#  'P_201.png',
#  'P_156.png',
#  'P_226.png',
#  'P_221.png',
#  'P_374.png',
#  'P_1_124.png',
#  'P_491.png',
#  'P_462.png',
#  'P_602.png',
#  'P_535.png',
#  'P_708.png',
#  'P_136.png',
#  'P_714.png',
#  'P_599.png',
#  'P_40.png',
#  'P_481.png',
#  'P_1_40.png',
#  'P_69.png',
#  'P_371.png',
#  'P_2_14.png',
#  'P_583.png',
#  'P_230.png',
#  'P_557.png',
#  'P_324.png',
#  'P_1_134.png',
#  'P_251.png',
#  'P_211.png',
#  'P_778.png',
#  'P_664.png',
#  'P_413.png',
#  'P_471.png',
#  'P_33.png',
#  'P_676.png',
#  'P_100.png',
#  'P_1_135.png',
#  'P_151.png',
#  'P_624.png',
#  'P_812.png',
#  'P_1_152.png',
#  'P_653.png',
#  'P_39.png',
#  'P_729.png',
#  'P_833.png',
#  'P_133.png',
#  'P_16.png',
#  'P_53.png',
#  'P_672.png',
#  'P_1_34.png',
#  'P_2_77.png',
#  'P_678.png',
#  'P_709.png',
#  'P_1_4.png',
#  'P_560.png',
#  'P_813.png',
#  'P_618.png',
#  'P_581.png',
#  'P_484.png',
#  'P_649.png',
#  'P_589.png',
#  'P_673.png',
#  'P_61.png',
#  'P_280.png',
#  'P_267.png',
#  'P_621.png',
#  'P_437.png',
#  'P_523.png',
#  'P_2_84.png',
#  'P_79.png',
#  'P_185.png',
#  'P_472.png',
#  'P_1_136.png',
#  'P_823.png',
#  'P_2_69.png',
#  'P_294.png',
#  'P_727.png',
#  'P_237.png',
#  'P_730.png',
#  'P_543.png',
#  'P_725.png',
#  'P_194.png',
#  'P_610.png',
#  'P_669.png',
#  'P_21.png',
#  'P_694.png',
#  'P_1_156.png',
#  'P_1_66.png',
#  'P_765.png',
#  'P_660.png',
#  'P_189.png',
#  'P_1_91.png',
#  'P_343.png',
#  'P_1_90.png',
#  'P_176.png',
#  'P_315.png',
#  'P_742.png',
#  'P_728.png',
#  'P_779.png',
#  'P_27.png',
#  'P_422.png',
#  'P_359.png',
#  'P_2_121.png',
#  'P_2_108.png',
#  'P_1_7.png',
#  'P_285.png',
#  'P_644.png',
#  'P_1_23.png',
#  'P_394.png',
#  'P_207.png',
#  'P_180.png',
#  'P_247.png',
#  'P_166.png',
#  'P_666.png',
#  'P_5.png',
#  'P_686.png',
#  'P_91.png',
#  'P_716.png',
#  'P_304.png',
#  'P_32.png',
#  'P_688.png',
#  'P_257.png',
#  'P_480.png',
#  'P_2_91.png',
#  'P_722.png',
#  'P_2_18.png',
#  'P_319.png',
#  'P_1_54.png',
#  'P_1_128.png',
#  'P_590.png',
#  'P_569.png',
#  'P_572.png',
#  'P_542.png',
#  'P_107.png',
#  'P_1_20.png',
#  'P_256.png',
#  'P_763.png',
#  'P_2_105.png',
#  'P_430.png',
#  'P_685.png',
#  'P_73.png',
#  'P_565.png',
#  'P_173.png',
#  'P_63.png',
#  'P_236.png',
#  'P_1_42.png',
#  'P_2_49.png',
#  'P_659.png',
#  'P_651.png',
#  'P_308.png',
#  'P_258.png',
#  'P_134.png',
#  'P_66.png',
#  'P_1_49.png',
#  'P_208.png',
#  'P_844.png',
#  'P_271.png',
#  'P_1_3.png',
#  'P_349.png',
#  'P_607.png',
#  'P_620.png',
#  'P_701.png',
#  'P_699.png',
#  'P_435.png',
#  'P_1_101.png',
#  'P_549.png',
#  'P_1_50.png',
#  'P_366.png',
#  'P_2_95.png',
#  'P_1_73.png',
#  'P_2_31.png',
#  'P_2_75.png',
#  'P_820.png',
#  'P_192.png',
#  'P_37.png',
#  'P_574.png',
#  'P_18.png',
#  'P_147.png',
#  'P_68.png',
#  'P_490.png',
#  'P_94.png',
#  'P_597.png',
#  'P_1_157.png',
#  'P_195.png',
#  'P_2_48.png',
#  'P_12.png',
#  'P_2_60.png',
#  'P_2_79.png',
#  'P_578.png',
#  'P_518.png',
#  'P_2_114.png',
#  'P_10.png',
#  'P_181.png',
#  'P_1_131.png',
#  'P_376.png',
#  'P_350.png',
#  'P_414.png',
#  'P_113.png',
#  'P_41.png',
#  'P_2_82.png',
#  'P_662.png',
#  'P_307.png',
#  'P_28.png',
#  'P_1_105.png',
#  'P_406.png',
#  'P_466.png',
#  'P_530.png',
#  'P_717.png',
#  'P_1_38.png',
#  'P_2_120.png',
#  'P_1_98.png',
#  'P_261.png',
#  'P_453.png',
#  'P_1_21.png',
#  'P_1_51.png',
#  'P_2_25.png',
#  'P_429.png',
#  'P_352.png',
#  'P_633.png',
#  'P_636.png',
#  'P_159.png',
#  'P_526.png',
#  'P_411.png',
#  'P_361.png',
#  'P_1_160.png',
#  'P_217.png',
#  'P_792.png',
#  'P_102.png',
#  'P_2_116.png',
#  'P_477.png',
#  'P_520.png',
#  'P_99.png',
#  'P_749.png',
#  'P_697.png',
#  'P_297.png',
#  'P_571.png',
#  'P_2_12.png',
#  'P_615.png',
#  'P_683.png',
#  'P_1_99.png',
#  'P_677.png',
#  'P_777.png',
#  'P_757.png',
#  'P_475.png',
#  'P_1_68.png',
#  'P_561.png',
#  'P_200.png',
#  'P_2_66.png',
#  'P_128.png',
#  'P_731.png',
#  'P_1_140.png',
#  'P_1_85.png',
#  'P_139.png',
#  'P_1_82.png',
#  'P_1_65.png',
#  ...]

# %%
# new folder path
path_resized = 'Resized_Trainset' #the path where to save resized images
# create new folder
if not os.path.exists(path_resized):
    os.makedirs(path_resized)

# %%
# new folder path
test_path_resized = 'Resized_Testset' #the path where to save resized images
# create new folder
if not os.path.exists(test_path_resized):
    os.makedirs(test_path_resized)

# %%
def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = PIL.Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((256,256), Image.ANTIALIAS)
            imResize.save('{}{}{}'.format(path_resized,'/',os.path.split(item)[1]))

resize()
# Out:
# /tmp/ipykernel_10275/2794608175.py:8: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   imResize = im.resize((256,256), Image.ANTIALIAS)

# %%
path = "TestSet/"
dirs = os.listdir( path )

path_resized = test_path_resized

resize()
# Out:
# /tmp/ipykernel_10275/2794608175.py:8: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   imResize = im.resize((256,256), Image.ANTIALIAS)
